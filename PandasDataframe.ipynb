# %% [markdown]
# <a href="https://colab.research.google.com/github/get-ayush/PythonLibraries/blob/main/PandasDataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# **Creating Dataframe**

# %%
#using List
student_dict = {
    "name" : ["Ayush","MSD","Rohit","Virat"],
    "Maths" : [45,78,12,89],
    "Science" : [78,45,12,89],
    "English" : [78,45,12,89]
}
student = pd.DataFrame(student_dict)
student.set_index("name",inplace=True)
student
# Out:
#        Maths  Science  English
# name
# Ayush     45       78       78
# MSD       78       45       45
# Rohit     12       12       12
# Virat     89       89       89

# %%
#Using Dict
student_data = {
    "Maths" : [78,45,12,89],
    "Science" : [78,45,12,89],
}
student = pd.DataFrame(student_data)
student
# Out:
#    Maths  Science
# 0     78       78
# 1     45       45
# 2     12       12
# 3     89       89

# %% [markdown]
# #using read_csv

# %%
movies = pd.read_csv("/content/movies.csv")
# print(movies)

# %%
ipl = pd.read_csv("/content/ipl-matches.csv")
ipl
# Out:
#           ID        City        Date   Season  MatchNumber  \
# 0    1312200   Ahmedabad  2022-05-29     2022        Final
# 1    1312199   Ahmedabad  2022-05-27     2022  Qualifier 2
# 2    1312198     Kolkata  2022-05-25     2022   Eliminator
# 3    1312197     Kolkata  2022-05-24     2022  Qualifier 1
# 4    1304116      Mumbai  2022-05-22     2022           70
# ..       ...         ...         ...      ...          ...
# 945   335986     Kolkata  2008-04-20  2007/08            4
# 946   335985      Mumbai  2008-04-20  2007/08            5
# 947   335984       Delhi  2008-04-19  2007/08            3
# 948   335983  Chandigarh  2008-04-19  2007/08            2
# 949   335982   Bangalore  2008-04-18  2007/08            1
#
#                            Team1                        Team2  \
# 0               Rajasthan Royals               Gujarat Titans
# 1    Royal Challengers Bangalore             Rajasthan Royals
# 2    Royal Challengers Bangalore         Lucknow Super Giants
# ...

# %% [markdown]
# # **Dataframe Attribues and Methods**

# %%
#shape
movies.shape
# Out:
# (1629, 18)

# %%
#dtype
movies.dtypes
ipl.dtypes
# Out:
# ID                   int64
# City                object
# Date                object
# Season              object
# MatchNumber         object
# Team1               object
# Team2               object
# Venue               object
# TossWinner          object
# TossDecision        object
# SuperOver           object
# WinningTeam         object
# WonBy               object
# Margin             float64
# method              object
# Player_of_Match     object
# Team1Players        object
# Team2Players        object
# Umpire1             object
# Umpire2             object
# dtype: object

# %%
#index
movies.index
ipl.index
# Out:
# RangeIndex(start=0, stop=950, step=1)

# %%
#columns
movies.columns
ipl.columns
student.columns
# Out:
# Index(['Maths', 'Science'], dtype='object')

# %%
#values
student.values
# Out:
# array([[78, 78],
#        [45, 45],
#        [12, 12],
#        [89, 89]])

# %%
#head & tail
movies.head(2)
ipl.tail(5)
# Out:
#          ID        City        Date   Season MatchNumber  \
# 945  335986     Kolkata  2008-04-20  2007/08           4
# 946  335985      Mumbai  2008-04-20  2007/08           5
# 947  335984       Delhi  2008-04-19  2007/08           3
# 948  335983  Chandigarh  2008-04-19  2007/08           2
# 949  335982   Bangalore  2008-04-18  2007/08           1
#
#                            Team1                        Team2  \
# 945        Kolkata Knight Riders              Deccan Chargers
# 946               Mumbai Indians  Royal Challengers Bangalore
# 947             Delhi Daredevils             Rajasthan Royals
# 948              Kings XI Punjab          Chennai Super Kings
# 949  Royal Challengers Bangalore        Kolkata Knight Riders
#
#                                           Venue                   TossWinner  \
# 945                                Eden Gardens              Deccan Chargers
# 946                            Wankhede Stadium               Mumbai Indians
# ...

# %%
#sample
ipl.sample(5)
# Out:
#           ID       City        Date Season MatchNumber                  Team1  \
# 702   501271    Chennai  2011-05-28   2011       Final    Chennai Super Kings
# 296  1136578    Kolkata  2018-04-21   2018          18  Kolkata Knight Riders
# 772   501200      Kochi  2011-04-09   2011           3   Kochi Tuskers Kerala
# 66   1304054     Mumbai  2022-04-01   2022           8           Punjab Kings
# 206  1178423  Hyderabad  2019-04-29   2019          48    Sunrisers Hyderabad
#
#                            Team2                               Venue  \
# 702  Royal Challengers Bangalore     MA Chidambaram Stadium, Chepauk
# 296              Kings XI Punjab                        Eden Gardens
# 772  Royal Challengers Bangalore                       Nehru Stadium
# 66         Kolkata Knight Riders            Wankhede Stadium, Mumbai
# 206              Kings XI Punjab  Rajiv Gandhi International Stadium
#
#                 TossWinner TossDecision SuperOver  \
# ...

# %%
#info
movies.info()
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1629 entries, 0 to 1628
# Data columns (total 18 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           1629 non-null   object
#  1   imdb_id           1629 non-null   object
#  2   poster_path       1526 non-null   object
#  3   wiki_link         1629 non-null   object
#  4   title_y           1629 non-null   object
#  5   original_title    1629 non-null   object
#  6   is_adult          1629 non-null   int64
#  7   year_of_release   1629 non-null   int64
#  8   runtime           1629 non-null   object
#  9   genres            1629 non-null   object
#  10  imdb_rating       1629 non-null   float64
#  11  imdb_votes        1629 non-null   int64
#  12  story             1609 non-null   object
#  13  summary           1629 non-null   object
#  14  tagline           557 non-null    object
#  15  actors            1624 non-null   object
# ...

# %%
#descibe
movies.describe()
# Out:
#        is_adult  year_of_release  imdb_rating     imdb_votes
# count    1629.0      1629.000000  1629.000000    1629.000000
# mean        0.0      2010.263966     5.557459    5384.263352
# std         0.0         5.381542     1.567609   14552.103231
# min         0.0      2001.000000     0.000000       0.000000
# 25%         0.0      2005.000000     4.400000     233.000000
# 50%         0.0      2011.000000     5.600000    1000.000000
# 75%         0.0      2015.000000     6.800000    4287.000000
# max         0.0      2019.000000     9.400000  310481.000000

# %%
#isnull
movies.isnull().sum()
# Out:
# title_x                0
# imdb_id                0
# poster_path          103
# wiki_link              0
# title_y                0
# original_title         0
# is_adult               0
# year_of_release        0
# runtime                0
# genres                 0
# imdb_rating            0
# imdb_votes             0
# story                 20
# summary                0
# tagline             1072
# actors                 5
# wins_nominations     922
# release_date         107
# dtype: int64

# %%
#Duplicated Row
movies.duplicated().sum()
# Out:
# np.int64(0)

# %%
import pandas as pd

# Re-initialize student DataFrame as it was likely overwritten to None
student_data = {
    "Maths" : [78,45,12,89],
    "Science" : [78,45,12,89],
}
student = pd.DataFrame(student_data)

# Rename the columns. The 'inplace=True' makes the operation modify the DataFrame
# in place and return None. If you want to assign the result back to 'student',
# you should remove 'inplace=True'.
# Correct way: either 'student = student.rename(...)', or 'student.rename(..., inplace=True)' without assignment.
student = student.rename(columns = { "Maths" : "Percent","Science" : "Physics"})
student
# Out:
#    Percent  Physics
# 0       78       78
# 1       45       45
# 2       12       12
# 3       89       89

# %%
print(student)
# Out:
#    Percent  Physics
# 0       78       78
# 1       45       45
# 2       12       12
# 3       89       89

# %% [markdown]
# # Math Methods

# %%
#sum -> axis argument
# students.sum()

# %%
student.sum(axis = 0)
# Out:
# Percent    224
# Physics    224
# dtype: int64

# %%
#min , max , median
# student.max()
student.max(axis = 1)
# Out:
# 0    78
# 1    45
# 2    12
# 3    89
# dtype: int64

# %% [markdown]
# # Selecting Colums from Dataframe

# %%
# Select one COlumn
ipl["Venue"]
# Out:
# 0                Narendra Modi Stadium, Ahmedabad
# 1                Narendra Modi Stadium, Ahmedabad
# 2                           Eden Gardens, Kolkata
# 3                           Eden Gardens, Kolkata
# 4                        Wankhede Stadium, Mumbai
#                           ...
# 945                                  Eden Gardens
# 946                              Wankhede Stadium
# 947                              Feroz Shah Kotla
# 948    Punjab Cricket Association Stadium, Mohali
# 949                         M Chinnaswamy Stadium
# Name: Venue, Length: 950, dtype: object

# %%
#Select Multiple Column
ipl[["Venue","WinningTeam","City","Date"]]
# ipl
# Out:
#                                           Venue                  WinningTeam  \
# 0              Narendra Modi Stadium, Ahmedabad               Gujarat Titans
# 1              Narendra Modi Stadium, Ahmedabad             Rajasthan Royals
# 2                         Eden Gardens, Kolkata  Royal Challengers Bangalore
# 3                         Eden Gardens, Kolkata               Gujarat Titans
# 4                      Wankhede Stadium, Mumbai                 Punjab Kings
# ..                                          ...                          ...
# 945                                Eden Gardens        Kolkata Knight Riders
# 946                            Wankhede Stadium  Royal Challengers Bangalore
# 947                            Feroz Shah Kotla             Delhi Daredevils
# 948  Punjab Cricket Association Stadium, Mohali          Chennai Super Kings
# 949                       M Chinnaswamy Stadium        Kolkata Knight Riders
#
#            City        Date
# ...

# %% [markdown]
# Selecting rows from Dataframe
#
# Iloc : Searches using index positions / We have to provide index
#
# loc : Searches using index labels / We have to provide name

# %%
#Single Row
type(movies.iloc[4])
# Out:
# pandas.core.series.Series

# %%
#Multiple Row
movies.iloc[5:16:2]
# Out:
#               title_x    imdb_id  \
# 5         Soni (film)  tt6078866
# 7          Bombairiya  tt4971258
# 9    Thackeray (film)  tt7777196
# 11          Gully Boy  tt2395469
# 13      Total Dhamaal  tt7639372
# 15  Badla (2019 film)  tt8130968
#
#                                           poster_path  \
# 5   https://upload.wikimedia.org/wikipedia/en/thum...
# 7   https://upload.wikimedia.org/wikipedia/en/thum...
# 9   https://upload.wikimedia.org/wikipedia/en/thum...
# 11  https://upload.wikimedia.org/wikipedia/en/thum...
# 13  https://upload.wikimedia.org/wikipedia/en/thum...
# 15  https://upload.wikimedia.org/wikipedia/en/0/0c...
#
#                                           wiki_link        title_y  \
# 5         https://en.wikipedia.org/wiki/Soni_(film)           Soni
# 7          https://en.wikipedia.org/wiki/Bombairiya     Bombairiya
# 9    https://en.wikipedia.org/wiki/Thackeray_(film)      Thackeray
# 11          https://en.wikipedia.org/wiki/Gully_Boy      Gully Boy
# ...

# %%
#fancy indexing
# movies.iloc[0,4,5]

# %%
#Loc
student.loc[0:2]
# Out:
#    Percent  Physics
# 0       78       78
# 1       45       45
# 2       12       12

# %% [markdown]
# # Selecting Both Rows and Comuns

# %%
movies.loc[0:3,"title_x" : "poster_path"]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
# 3                       Why Cheat India  tt8108208
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...
# 3  https://upload.wikimedia.org/wikipedia/en/thum...

# %%
movies.iloc[0:3,0:3]
# Out:
#                                 title_x    imdb_id  \
# 0              Uri: The Surgical Strike  tt8291224
# 1                         Battalion 609  tt9472208
# 2  The Accidental Prime Minister (film)  tt6986710
#
#                                          poster_path
# 0  https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                NaN
# 2  https://upload.wikimedia.org/wikipedia/en/thum...

# %% [markdown]
# # Filters a Data Frame

# %%
#Find all the winners of the season in the dataframe
mask = ipl["MatchNumber"] == "Final"
NewDF = ipl[mask]
NewDF[["Season","WinningTeam"]]
# Out:
#       Season            WinningTeam
# 0       2022         Gujarat Titans
# 74      2021    Chennai Super Kings
# 134  2020/21         Mumbai Indians
# 194     2019         Mumbai Indians
# 254     2018    Chennai Super Kings
# 314     2017         Mumbai Indians
# 373     2016    Sunrisers Hyderabad
# 433     2015         Mumbai Indians
# 492     2014  Kolkata Knight Riders
# 552     2013         Mumbai Indians
# 628     2012  Kolkata Knight Riders
# 702     2011    Chennai Super Kings
# 775  2009/10    Chennai Super Kings
# 835     2009        Deccan Chargers
# 892  2007/08       Rajasthan Royals

# %%
#How many Super Over finished have Occured
ipl[ipl["SuperOver"] == "Y"].shape[0]
# Out:
# 14

# %%
#how many matches has csk won in Kolkata
mask = ipl[(ipl["City"] == "Kolkata") & (ipl["WinningTeam"] == "Chennai Super Kings")].shape[0]
mask
# Out:
# 5

# %%
#toss winner is match winner in percentage
ipl [ipl["TossWinner"] == ipl["WinningTeam"]].shape[0]/ipl.shape[0]*100
# Out:
# 51.473684210526315

# %%
#Movies with Rating Higher than 8 and votes >10000
movies[(movies["imdb_rating"] > 8) & (movies["imdb_votes"] > 10000)].shape[0]
# Out:
# 43

# %%
#Action movies with rating higher than 7.5
# movies[(movies["genres"].str.split("|").apply(lambda x :"Action" in x ) ) & (movies["imdb_rating"] > 7.5)].shape[0]
movies[(movies["genres"].str.contains("Action") ) & (movies["imdb_rating"] > 7.5)].shape[0]
# Out:
# 33

# %%
# Write a function that can return the track record of 2 teams against each other
def get_track_record(team1, team2):
    # Filter matches where both teams played against each other
    mask = ((ipl['Team1'] == team1) & (ipl['Team2'] == team2)) | ((ipl['Team1'] == team2) & (ipl['Team2'] == team1))
    temp_df = ipl[mask]

    total_matches = temp_df.shape[0]
    if total_matches == 0:
        return f'No matches found between {team1} and {team2}.'

    team1_wins = temp_df[temp_df['WinningTeam'] == team1].shape[0]
    team2_wins = temp_df[temp_df['WinningTeam'] == team2].shape[0]
    draws_or_no_result = total_matches - (team1_wins + team2_wins)

    result = {
        'Total Matches': total_matches,
        team1: team1_wins,
        team2: team2_wins,
        'No Result/Draw': draws_or_no_result
    }
    return result

# Example usage:
print(get_track_record('Chennai Super Kings', 'Mumbai Indians'))
# Out:
# {'Total Matches': 34, 'Chennai Super Kings': 14, 'Mumbai Indians': 20, 'No Result/Draw': 0}

# %% [markdown]
# # Adding New Columns

# %%
movies["Country"] = "India"
movies
# Out:
#                                    title_x     imdb_id  \
# 0                 Uri: The Surgical Strike   tt8291224
# 1                            Battalion 609   tt9472208
# 2     The Accidental Prime Minister (film)   tt6986710
# 3                          Why Cheat India   tt8108208
# 4                          Evening Shadows   tt6028796
# ...                                    ...         ...
# 1624                 Tera Mera Saath Rahen   tt0301250
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1626                       Sabse Bada Sukh   tt0069204
# 1627                                 Daaka  tt10833860
# 1628                              Humsafar   tt2403201
#
#                                             poster_path  \
# 0     https://upload.wikimedia.org/wikipedia/en/thum...
# 1                                                   NaN
# 2     https://upload.wikimedia.org/wikipedia/en/thum...
# 3     https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#From Existing Ones
movies.dropna(inplace=True)
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 298 entries, 11 to 1623
# Data columns (total 19 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   title_x           298 non-null    object
#  1   imdb_id           298 non-null    object
#  2   poster_path       298 non-null    object
#  3   wiki_link         298 non-null    object
#  4   title_y           298 non-null    object
#  5   original_title    298 non-null    object
#  6   is_adult          298 non-null    int64
#  7   year_of_release   298 non-null    int64
#  8   runtime           298 non-null    object
#  9   genres            298 non-null    object
#  10  imdb_rating       298 non-null    float64
#  11  imdb_votes        298 non-null    int64
#  12  story             298 non-null    object
#  13  summary           298 non-null    object
#  14  tagline           298 non-null    object
#  15  actors            298 non-null    object
# ...

# %%
movies["Lead Actor"] = movies["actors"].str.split("|").apply(lambda x:x[0])
movies
# Out:
#                       title_x     imdb_id  \
# 11                  Gully Boy   tt2395469
# 34              Yeh Hai India   tt5525846
# 37          Article 15 (film)  tt10324144
# 87                    Aiyaary   tt6774212
# 96           Raid (2018 film)   tt7363076
# ...                       ...         ...
# 1600                   Kasoor   tt0272688
# 1601         Maya (2001 film)   tt0299027
# 1607  Nayak (2001 Hindi film)   tt0291376
# 1621                  Tum Bin   tt0290326
# 1623                 Zubeidaa   tt0255713
#
#                                             poster_path  \
# 11    https://upload.wikimedia.org/wikipedia/en/thum...
# 34    https://upload.wikimedia.org/wikipedia/en/thum...
# 37    https://upload.wikimedia.org/wikipedia/en/thum...
# 87    https://upload.wikimedia.org/wikipedia/en/thum...
# 96    https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1600  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %% [markdown]
# # Important Dataframe Functions

# %% [markdown]
# #Astype :
# Change the type of the data and reduce the size like coverting int64 to int32

# %%
ipl.info()

ipl["ID"] = ipl["ID"].astype("int32")
ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int64
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    object
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    object
#  6   Team2            950 non-null    object
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %%
ipl["Season"] = ipl["Season"].astype("category")
ipl["Team1"] = ipl["Team1"].astype("category")
ipl["Team2"] = ipl["Team2"].astype("category")


ipl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 950 entries, 0 to 949
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ID               950 non-null    int32
#  1   City             899 non-null    object
#  2   Date             950 non-null    object
#  3   Season           950 non-null    category
#  4   MatchNumber      950 non-null    object
#  5   Team1            950 non-null    category
#  6   Team2            950 non-null    category
#  7   Venue            950 non-null    object
#  8   TossWinner       950 non-null    object
#  9   TossDecision     950 non-null    object
#  10  SuperOver        946 non-null    object
#  11  WinningTeam      946 non-null    object
#  12  WonBy            950 non-null    object
#  13  Margin           932 non-null    float64
#  14  method           19 non-null     object
#  15  Player_of_Match  946 non-null    object
# ...

# %% [markdown]
# # DataFrame Methods

# %%
#Value Count : Generates the frequency count of particular row in a dataframe
marks = pd.DataFrame ([
    [ 100 , 80 , 10 ],
    [ 100 , 80 , 10 ],
    [ 10 , 70 , 10 ],
    [ 99 , 84 , 11 ]
] , columns = ["iq","marks","package"])
marks.value_counts()
# Out:
# iq   marks  package
# 100  80     10         2
# 10   70     10         1
# 99   84     11         1
# Name: count, dtype: int64

# %%
# Find Which Player has won most POTM in finals and Qualifier
# We filter for 'Qualifier' or 'Final' in MatchNumber, then access the 'Player_of_Match' column and count values
result = ipl[ipl['MatchNumber'].str.contains('Qualifier|Final')]['Player_of_Match'].value_counts()
result.head()
# Out:
# Player_of_Match
# F du Plessis    3
# KA Pollard      3
# MK Pandey       2
# SR Watson       2
# JJ Bumrah       2
# Name: count, dtype: int64

# %%
#Toss Decision Plot

ipl["TossDecision"].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='count'>

# %%
#How many matches has every team played
(ipl["Team1"].value_counts() + ipl["Team2"].value_counts()).sort_values(ascending=False)
# Out:
# Mumbai Indians                 231
# Royal Challengers Bangalore    226
# Kolkata Knight Riders          223
# Chennai Super Kings            208
# Rajasthan Royals               192
# Kings XI Punjab                190
# Delhi Daredevils               161
# Sunrisers Hyderabad            152
# Deccan Chargers                 75
# Delhi Capitals                  63
# Pune Warriors                   46
# Gujarat Lions                   30
# Punjab Kings                    28
# Gujarat Titans                  16
# Rising Pune Supergiant          16
# Lucknow Super Giants            15
# Kochi Tuskers Kerala            14
# Rising Pune Supergiants         14
# Name: count, dtype: int64

# %% [markdown]
# #Sort Values
#
# (Series and Dataframe) Ascending , Na Position , Inplace , Multiple Columns

# %%
x = pd.Series([12,78,99,11])
x.sort_values(ascending = True)
# Out:
# 3    11
# 0    12
# 1    78
# 2    99
# dtype: int64

# %%
movies = pd.read_csv("/content/movies.csv")
movies.sort_values("title_x" , ascending = False)
# Out:
#                        title_x    imdb_id  \
# 1623                  Zubeidaa  tt0255713
# 939      Zor Lagaa Ke...Haiya!  tt1479857
# 756                   Zokkomon  tt1605790
# 670          Zindagi Tere Naam  tt2164702
# 778   Zindagi Na Milegi Dobara  tt1562872
# ...                        ...        ...
# 1039          1971 (2007 film)  tt0983990
# 723     1920: The Evil Returns  tt2222550
# 287               1920: London  tt5638500
# 1021               1920 (film)  tt1301698
# 1498        16 December (film)  tt0313844
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 939   https://upload.wikimedia.org/wikipedia/en/thum...
# 756   https://upload.wikimedia.org/wikipedia/en/thum...
# 670   https://upload.wikimedia.org/wikipedia/en/thum...
# 778   https://upload.wikimedia.org/wikipedia/en/thum...
# ...                                                 ...
# 1039  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
# Creating Multiple FIlters
movies.sort_values(["year_of_release","title_x"] ,ascending = [True,False])
# Out:
#                                    title_x     imdb_id  \
# 1623                              Zubeidaa   tt0255713
# 1625                  Yeh Zindagi Ka Safar   tt0298607
# 1622         Yeh Teraa Ghar Yeh Meraa Ghar   tt0298606
# 1620              Yeh Raaste Hain Pyaar Ke   tt0292740
# 1573                   Yaadein (2001 film)   tt0248617
# ...                                    ...         ...
# 37                       Article 15 (film)  tt10324144
# 46                           Arjun Patiala   tt7881524
# 10                                  Amavas   tt8396186
# 26    Albert Pinto Ko Gussa Kyun Aata Hai?   tt4355838
# 21                                22 Yards   tt9496212
#
#                                             poster_path  \
# 1623  https://upload.wikimedia.org/wikipedia/en/thum...
# 1625  https://upload.wikimedia.org/wikipedia/en/thum...
# 1622  https://upload.wikimedia.org/wikipedia/en/thum...
# 1620  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#rank(Series)
batsman = pd.read_csv("/content/batsman_runs_ipl.csv")
batsman.sample(5)
batsman["batting_rank"] = batsman["batsman_run"].rank(ascending=False)
batsman.sort_values("batting_rank")
# Out:
#              batter  batsman_run  batting_rank
# 569         V Kohli         6634           1.0
# 462        S Dhawan         6244           2.0
# 130       DA Warner         5883           3.0
# 430       RG Sharma         5881           4.0
# 493        SK Raina         5536           5.0
# ..              ...          ...           ...
# 570  V Pratap Singh            0         594.0
# 63     Abdur Razzak            0         594.0
# 562          U Kaul            0         594.0
# 65       Akash Deep            0         594.0
# 57           AS Roy            0         594.0
#
# [605 rows x 3 columns]

# %%
#sort index(series and Dataframe)

marks = {
    "Maths": 67,
    "English" : 78,
    "Science" : 74,
    "Python" : 56
}
marks_series = pd.Series(marks)
marks_series.sort_index(ascending = False)
# Out:
# Science    74
# Python     56
# Maths      67
# English    78
# dtype: int64

# %%
#set-index(Dataframe): We can place one column as the index of the dataframe
batsman.set_index("batter" , inplace=True)

# %%
#reset_index(series + dataframe)
batsman.reset_index(inplace=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1703/1788484402.py in <cell line: 0>()
#       1 #reset_index(series + dataframe)
# ----> 2 batsman.reset_index(inplace=True)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in reset_index(self, level, drop, inplace, col_level, col_fill, allow_duplicates, names)
#    6470                     )
#    6471
# -> 6472                 new_obj.insert(
#    6473                     0,
#    6474                     name,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    5156         if not allow_duplicates and column in self.columns:
#    5157             # Should this be a different kind of error??
# -> 5158             raise ValueError(f"cannot insert {column}, already exists")
#    5159         if not is_integer(loc):
# ...

# %%
#how to replace existing index without loosing
# batsman.reset_index().set_index("batting_rank")(Datframe)
type(marks_series.reset_index())
# Out:
# pandas.core.frame.DataFrame

# %%
#rename(dataframe) ->index
# movies.set_index("title_x",inplace=True)
movies.rename(columns = {"imdb_id" : "imdb" , "poster_path" :"poster link"},inplace=True)

# %%
movies.rename(index = { "Uri: The Surgical Strike" : "URI", "Battalion 609" :"Battalion"},inplace = True)

# %%
movies
# Out:
#                                             imdb  \
# title_x
# URI                                    tt8291224
# Battalion                              tt9472208
# The Accidental Prime Minister (film)   tt6986710
# Why Cheat India                        tt8108208
# Evening Shadows                        tt6028796
# ...                                          ...
# Tera Mera Saath Rahen                  tt0301250
# Yeh Zindagi Ka Safar                   tt0298607
# Sabse Bada Sukh                        tt0069204
# Daaka                                 tt10833860
# Humsafar                               tt2403201
#
#                                                                             poster link  \
# title_x
# URI                                   https://upload.wikimedia.org/wikipedia/en/thum...
# Battalion                                                                           NaN
# The Accidental Prime Minister (film)  https://upload.wikimedia.org/wikipedia/en/thum...
# ...

# %%
#unique(Series) Will also count Missing Values
len(ipl["Season"].unique())
# Out:
# 15

# %%
#nunique(Series & Dataframe) Will not count Missing Values
ipl["Season"].nunique()
# Out:
# 15

# %%
#isnull(series & Dataframe): Ask the particular every number that you are  null value or not
student [student["Percent"].isnull()] #(For Series)
student.isnull() #For Dataframe
# Out:
#    Percent  Physics
# 0    False    False
# 1    False    False
# 2    False    False
# 3    False    False

# %%
#notnull(series & dataframe): It is just opposite of the isnull function in which it also add not operator
student["Percent"].notnull() #(For Series)
student.notnull() #For Dataframe
# Out:
#    Percent  Physics
# 0     True     True
# 1     True     True
# 2     True     True
# 3     True     True

# %%
#hasnans(series)
student["Percent"].hasnans
# Out:
# False

# %% [markdown]
# # Dropna : Removes the missing values from a dataframe and series

# %%
import numpy as np

student['OptionalSubject'] = [70, np.nan, 85, np.nan]

display(student)
# Out:
#    Percent  Physics  NanCol  OptionalSubject  (Percent, 1)
# 0      NaN       78      78             70.0            77
# 1      NaN       45      78              NaN            77
# 2      NaN       12      17             85.0            77
# 3      NaN       89      12              NaN            77

# %%
student = student.drop(columns=['(Percent, 1)'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_1703/1592562727.py in <cell line: 0>()
# ----> 1 student = student.drop(columns=['(Percent, 1)'])
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
# First, let's add a dummy column 'NanCol' to demonstrate deletion
student['NanCol'] = [78, 78, 17, 12]
display(student)

# Now, let's delete the 'NanCol' column
student = student.drop('NanCol', axis=1)
display(student)
# Out:
#    Percent  Physics  NanCol  OptionalSubject  (Percent, 1)
# 0      NaN       78      78             70.0            77
# 1      NaN       45      78              NaN            77
# 2      NaN       12      17             85.0            77
# 3      NaN       89      12              NaN            77
#    Percent  Physics  OptionalSubject  (Percent, 1)
# 0      NaN       78             70.0            77
# 1      NaN       45              NaN            77
# 2      NaN       12             85.0            77
# 3      NaN       89              NaN            77

# %%
#dropna(series & Dataframe ) Removes the all missing values from a dataframe and series
student["OptionalSubject"].dropna()#For Series
student
# Out:
#    Percent  Physics  NanCol  OptionalSubject
# 0       78       78      78             70.0
# 1       45       45      78              NaN
# 2       12       12      17             85.0
# 3       89       89      12              NaN

# %%
student.dropna()#for dataframe
# Out:
#    Percent  Physics  NanCol  OptionalSubject
# 0       78       78      78             70.0
# 2       12       12      17             85.0

# %%
student.dropna(how="all") #Remove the row that every column has Null Values
# Out:
#    Percent  Physics  NanCol  OptionalSubject
# 0       78       78      78             70.0
# 1       45       45      78              NaN
# 2       12       12      17             85.0
# 3       89       89      12              NaN

# %%
student.dropna(how="any") # Removes the all rows that have Null Values
# Out:
#    Percent  Physics  NanCol  OptionalSubject
# 0       78       78      78             70.0
# 2       12       12      17             85.0

# %%
# student["Percent"] = np.nan
# student ["Percent",1].drop()

student["Percent"] = [45,"Ayush" , "OPPP", np.nan]
student
# Out:
# 0                            70.0
# 1                            89.0
# 2                            85.0
# 3                            89.0
# Percent    [45, Ayush, OPPP, nan]
# Name: OptionalSubject, dtype: object

# %%
student.dropna(subset = ["Percent"]) #Gives only the rows of Percent that has no null values in the Percent column
# Out:
#   Percent  Physics  OptionalSubject
# 0      45       78             70.0
# 1   Ayush       45              NaN
# 2    OPPP       12             85.0

# %%
# when we want to filter out null values with different columns
student.dropna(subset = ["Percent","OptionalSubject"] , inplace=True)
# Out:
#   Percent  Physics  OptionalSubject
# 0      45       78             70.0
# 2    OPPP       12             85.0

# %% [markdown]
# # Fillna : Replace the Null values with the value you want

# %%
# student["OptionalSubject"].fillna(89)# For Series
# student.fillna(0)
display (student)
# Out:
# 0                            70.0
# 1                            89.0
# 2                            85.0
# 3                            89.0
# Percent    [45, Ayush, OPPP, nan]
# Name: OptionalSubject, dtype: object

# %%
#drop duplicate (Series & Dataframe) works like and -> duplicated()
series = pd.Series ([ 23, 45 ,67 ,12,12,67,23,45])# For series
# series.drop_duplicates()

#Dataframe
student_data = {
    "Maths" : [78,45,12,12,89],
    "Science" : [78,45,12,12,89],
    "SSt": [78,45,12,12,89]
}
student = pd.DataFrame(student_data)
student.drop_duplicates(keep ="last")
# Out:
#    Maths  Science  SSt
# 0     78       78   78
# 1     45       45   45
# 3     12       12   12
# 4     89       89   89

# %%
# #Find the last match played by Virat Kohli in Delhi with the help of drop duplicate
# ipl[Venue == "Feroz Shah Kotla" & "Team1" | "Team2" == "Royal Challengers Bangalore"]
ipl["all_players"] = ipl["Team1Players"] + ipl["Team2Players"]
ipl.head()
# Out:
#         ID       City        Date Season  MatchNumber  \
# 0  1312200  Ahmedabad  2022-05-29   2022        Final
# 1  1312199  Ahmedabad  2022-05-27   2022  Qualifier 2
# 2  1312198    Kolkata  2022-05-25   2022   Eliminator
# 3  1312197    Kolkata  2022-05-24   2022  Qualifier 1
# 4  1304116     Mumbai  2022-05-22   2022           70
#
#                          Team1                 Team2  \
# 0             Rajasthan Royals        Gujarat Titans
# 1  Royal Challengers Bangalore      Rajasthan Royals
# 2  Royal Challengers Bangalore  Lucknow Super Giants
# 3             Rajasthan Royals        Gujarat Titans
# 4          Sunrisers Hyderabad          Punjab Kings
#
#                               Venue            TossWinner TossDecision  ...  \
# 0  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals          bat  ...
# 1  Narendra Modi Stadium, Ahmedabad      Rajasthan Royals        field  ...
# 2             Eden Gardens, Kolkata  Lucknow Super Giants        field  ...
# ...

# %%
def did_Kohli_play(players_list):
  return "V Kohli" in players_list

# %%
ipl["did_Kohli_Play"] = ipl["all_players"].apply(did_Kohli_play)
ipl[(ipl["City"] == "Delhi") & (ipl["did_Kohli_Play"] == True)].drop_duplicates(subset = ['City',"did_Kohli_Play"],keep = 'first')
# Out:
#           ID   City        Date Season MatchNumber           Team1  \
# 208  1178421  Delhi  2019-04-28   2019          46  Delhi Capitals
#
#                            Team2                 Venue      TossWinner  \
# 208  Royal Challengers Bangalore  Arun Jaitley Stadium  Delhi Capitals
#
#     TossDecision  ... WonBy Margin method  Player_of_Match  \
# 208          bat  ...  Runs   16.0    NaN         S Dhawan
#
#                                           Team1Players  \
# 208  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#                                           Team2Players       Umpire1  \
# 208  ['PA Patel', 'V Kohli', 'AB de Villiers', 'S D...  BNJ Oxenford
#
#                    Umpire2                                        all_players  \
# 208  KN Ananthapadmanabhan  ['PP Shaw', 'S Dhawan', 'SS Iyer', 'RR Pant', ...
#
#     did_Kohli_Play
# 208           True
#
# [1 rows x 22 columns]

# %%
#drop (series & Dataframe)
temp = pd.Series([10,2,3,0,10,78])#Series
temp.drop(index = [0,3])# it will delete the indices value that is on index 0 and 3
# Out:
# 1     2
# 2     3
# 4    10
# 5    78
# dtype: int64

# %%
student #Dataframe for dropping/deleting multiple columns
student.drop(columns = ["SSt","Maths"])
# Out:
#    Science
# 0       78
# 1       45
# 2       12
# 3       12
# 4       89

# %%
#For Dropping /deleting multiple rows
student.drop(index = [0,2])
# Out:
#    Maths  Science  SSt
# 1     45       45   45
# 3     12       12   12
# 4     89       89   89

# %% [markdown]
# Apply Function (Series & Dataframe)
